# %% [markdown]
# <a href="https://colab.research.google.com/github/Dennisogaka/Explanatory-Data-Analysis/blob/main/EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
crops = pd.read_csv("crops.csv") # importing the file
crops.head() # the first five rows
crops.tail() # the last five rows
crops.info() # the table information on all columns (null & non-null values)
crops.describe() # the statistical description of the dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 20 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Farmer Name               500 non-null    object
#  1   County                    460 non-null    object
#  2   Crop Type                 463 non-null    object
#  3   Crop Variety              469 non-null    object
#  4   Season                    470 non-null    object
#  5   Planted Area (Acres)      489 non-null    object
#  6   Yield (Kg)                482 non-null    object
#  7   Market Price (KES/Kg)     483 non-null    object
#  8   Revenue (KES)             429 non-null    float64
#  9   Cost of Production (KES)  481 non-null    object
#  10  Profit (KES)              404 non-null    float64
#  11  Planting Date             483 non-null    object
#  12  Harvest Date              490 non-null    object
# ...

# %%
crops.columns #the columns we have in our dataset
crops.shape # the total number of rows vs columns
# Out:
# (500, 20)

# %%
crops.isnull().sum() # total null values in every column
# Out:
# Farmer Name                   0
# County                       40
# Crop Type                    37
# Crop Variety                 31
# Season                       30
# Planted Area (Acres)         11
# Yield (Kg)                   18
# Market Price (KES/Kg)        17
# Revenue (KES)                71
# Cost of Production (KES)     19
# Profit (KES)                 96
# Planting Date                17
# Harvest Date                 10
# Soil Type                    29
# Irrigation Method           151
# Fertilizer Used             133
# Pest Control                181
# Weather Impact              185
# Farmer Contact               16
# Notes                       199
# dtype: int64

# %%
crops.nunique() #identifies number of unique values per column
# Out:
# Farmer Name                 500
# County                       11
# Crop Type                    11
# Crop Variety                  4
# Season                        4
# Planted Area (Acres)        427
# Yield (Kg)                  474
# Market Price (KES/Kg)       460
# Revenue (KES)               429
# Cost of Production (KES)    470
# Profit (KES)                404
# Planting Date               269
# Harvest Date                265
# Soil Type                     6
# Irrigation Method             4
# Fertilizer Used               5
# Pest Control                  3
# Weather Impact                3
# Farmer Contact              311
# Notes                         4
# dtype: int64

# %%
crops.duplicated().sum() # determines existing duplicates in a dataset
# Out:
# np.int64(0)

# %%
(crops[crops["County"]=="Nairobi"]).head()
# Out:
#    Farmer Name   County Crop Type Crop Variety       Season  \
# 8     Farmer 9  Nairobi   Cassava       Hybrid  Short Rains
# 14   Farmer 15  Nairobi     Maize       Hybrid   Dry Season
# 43   Farmer 44  Nairobi    Coffee        Local  Short Rains
# 47   Farmer 48  Nairobi       Tea          NaN   Dry Season
# 64   Farmer 65  Nairobi    Coffee        Local  Short Rains
#
#    Planted Area (Acres) Yield (Kg) Market Price (KES/Kg)  Revenue (KES)  \
# 8                 11.03    4757.72                 27.42     1438937.21
# 14                 1.72    2625.34                113.38      511977.00
# 43                 1.96    4944.46                 60.98      590965.81
# 47                  6.7    2761.09                184.54     3413861.38
# 64                11.38    2553.22                 43.99     1278157.76
#
#    Cost of Production (KES)  Profit (KES) Planting Date Harvest Date  \
# 8                  21508.58    1417428.63    2023-03-31   2023-04-14
# ...

# %%
crops[(crops["County"]=="Nairobi") & (crops["Crop Type"]=="Tea")].head()
# Out:
#     Farmer Name   County Crop Type Crop Variety       Season  \
# 47    Farmer 48  Nairobi       Tea          NaN   Dry Season
# 213  Farmer 214  Nairobi       Tea          NaN   Dry Season
# 294  Farmer 295  Nairobi       Tea        Local   Long Rains
# 308  Farmer 309  Nairobi       Tea        Local  Short Rains
# 433  Farmer 434  Nairobi       Tea       Hybrid   Dry Season
#
#     Planted Area (Acres) Yield (Kg) Market Price (KES/Kg)  Revenue (KES)  \
# 47                   6.7    2761.09                184.54     3413861.38
# 213                 2.55      Error                111.51            NaN
# 294                 7.22    4761.61                 80.71     2774714.90
# 308                 3.84    3225.04                   NaN            NaN
# 433                Error    4886.09                 71.07            NaN
#
#     Cost of Production (KES)  Profit (KES) Planting Date Harvest Date  \
# 47                  29000.07    3384861.31    2023-10-03   2024-02-15
# ...

# %%
crops[(crops["County"]=="Nairobi") & (crops["Crop Type"]=="Tea")].tail()
# Out:
#     Farmer Name   County Crop Type Crop Variety       Season  \
# 213  Farmer 214  Nairobi       Tea          NaN   Dry Season
# 294  Farmer 295  Nairobi       Tea        Local   Long Rains
# 308  Farmer 309  Nairobi       Tea        Local  Short Rains
# 433  Farmer 434  Nairobi       Tea       Hybrid   Dry Season
# 456  Farmer 457  Nairobi       Tea       Hybrid   Dry Season
#
#     Planted Area (Acres) Yield (Kg) Market Price (KES/Kg)  Revenue (KES)  \
# 213                 2.55      Error                111.51            NaN
# 294                 7.22    4761.61                 80.71     2774714.90
# 308                 3.84    3225.04                   NaN            NaN
# 433                Error    4886.09                 71.07            NaN
# 456                14.36    2245.98                112.04     3613544.64
#
#     Cost of Production (KES)  Profit (KES) Planting Date Harvest Date  \
# 213                 65188.69           NaN    2023-11-09   2024-02-17
# ...

# %%
crops[(crops["County"]=="Nairobi") & (crops["Crop Type"]=="Tea")]
# Out:
#     Farmer Name   County Crop Type Crop Variety       Season  \
# 47    Farmer 48  Nairobi       Tea          NaN   Dry Season
# 213  Farmer 214  Nairobi       Tea          NaN   Dry Season
# 294  Farmer 295  Nairobi       Tea        Local   Long Rains
# 308  Farmer 309  Nairobi       Tea        Local  Short Rains
# 433  Farmer 434  Nairobi       Tea       Hybrid   Dry Season
# 456  Farmer 457  Nairobi       Tea       Hybrid   Dry Season
#
#     Planted Area (Acres) Yield (Kg) Market Price (KES/Kg)  Revenue (KES)  \
# 47                   6.7    2761.09                184.54     3413861.38
# 213                 2.55      Error                111.51            NaN
# 294                 7.22    4761.61                 80.71     2774714.90
# 308                 3.84    3225.04                   NaN            NaN
# 433                Error    4886.09                 71.07            NaN
# 456                14.36    2245.98                112.04     3613544.64
#
# ...

# %%
crops[(crops["County"]=="Nairobi") & (crops["Crop Type"]=="Tea")].describe()
# Out:
#        Revenue (KES)  Profit (KES)
# count   3.000000e+00  2.000000e+00
# mean    3.267374e+06  3.482908e+06
# std     4.381813e+05  1.386593e+05
# min     2.774715e+06  3.384861e+06
# 25%     3.094288e+06  3.433885e+06
# 50%     3.413861e+06  3.482908e+06
# 75%     3.513703e+06  3.531932e+06
# max     3.613545e+06  3.580955e+06

# %%
crops.sort_values(['County', 'Crop Type'], ascending=(True, True))
# Out:
#     Farmer Name   County Crop Type Crop Variety       Season  \
# 60    Farmer 61  Eldoret     Beans          NaN   Dry Season
# 128  Farmer 129  Eldoret     Beans        Error        Error
# 174  Farmer 175  Eldoret     Beans        Local   Long Rains
# 178  Farmer 179  Eldoret     Beans        Local  Short Rains
# 188  Farmer 189  Eldoret     Beans        Local   Long Rains
# ..          ...      ...       ...          ...          ...
# 68    Farmer 69      NaN       NaN      Organic   Dry Season
# 383  Farmer 384      NaN       NaN        Local  Short Rains
# 423  Farmer 424      NaN       NaN       Hybrid  Short Rains
# 446  Farmer 447      NaN       NaN        Local   Dry Season
# 484  Farmer 485      NaN       NaN       Hybrid   Long Rains
#
#     Planted Area (Acres) Yield (Kg) Market Price (KES/Kg)  Revenue (KES)  \
# 60                  18.9    1898.71                118.12     4238809.32
# 128                 6.33    3108.62                  62.0     1220009.01
# ...

# %%
crops.sort_values(['County'], ascending=(True))
# Out:
#     Farmer Name   County Crop Type Crop Variety       Season  \
# 67    Farmer 68  Eldoret   Sorghum        Local   Long Rains
# 35    Farmer 36  Eldoret     Error      Organic  Short Rains
# 115  Farmer 116  Eldoret   Sorghum      Organic   Long Rains
# 38    Farmer 39  Eldoret       NaN       Hybrid   Dry Season
# 418  Farmer 419  Eldoret       Tea        Local   Long Rains
# ..          ...      ...       ...          ...          ...
# 461  Farmer 462      NaN  Tomatoes       Hybrid   Dry Season
# 465  Farmer 466      NaN      Rice        Local   Dry Season
# 484  Farmer 485      NaN       NaN       Hybrid   Long Rains
# 487  Farmer 488      NaN       Tea          NaN   Long Rains
# 497  Farmer 498      NaN     Beans      Organic   Dry Season
#
#     Planted Area (Acres) Yield (Kg) Market Price (KES/Kg)  Revenue (KES)  \
# 67                   3.5    1703.96                 26.54      158280.84
# 35                 12.53    4006.27                123.45     6197012.61
# ...

# %%
crops.rename({'Crop Variety': 'COP','Market Price':'MP' }, axis=1, inplace=True)
crops
# Out:
#     Farmer Name    County Crop Type      COP       Season  \
# 0      Farmer 1    Kiambu  Potatoes  Organic   Long Rains
# 1      Farmer 2      Meru    Coffee    Local  Short Rains
# 2      Farmer 3    Nakuru   Sorghum    Error   Long Rains
# 3      Farmer 4   Eldoret  Potatoes  Organic  Short Rains
# 4      Farmer 5  Machakos  Tomatoes   Hybrid  Short Rains
# ..          ...       ...       ...      ...          ...
# 495  Farmer 496   Eldoret  Potatoes   Hybrid   Dry Season
# 496  Farmer 497   Eldoret     Beans   Hybrid   Dry Season
# 497  Farmer 498       NaN     Beans  Organic   Dry Season
# 498  Farmer 499   Kericho   Cassava   Hybrid   Dry Season
# 499  Farmer 500      Meru       Tea  Organic   Dry Season
#
#     Planted Area (Acres) Yield (Kg) Market Price (KES/Kg)  Revenue (KES)  \
# 0                  15.14    1654.76                100.19     2510066.72
# 1                  13.54    1957.61                168.63     4469713.42
# ...

# %%
crops.rename({'Cost of Production (KES)':"COP",'Crop Type': "CP"}, axis=1, inplace=True)
crops.head()
# Out:
#   Farmer Name    County        CP      COP       Season Planted Area (Acres)  \
# 0    Farmer 1    Kiambu  Potatoes  Organic   Long Rains                15.14
# 1    Farmer 2      Meru    Coffee    Local  Short Rains                13.54
# 2    Farmer 3    Nakuru   Sorghum    Error   Long Rains                19.33
# 3    Farmer 4   Eldoret  Potatoes  Organic  Short Rains                 1.56
# 4    Farmer 5  Machakos  Tomatoes   Hybrid  Short Rains                13.93
#
#   Yield (Kg) Market Price (KES/Kg)  Revenue (KES)       COP  Profit (KES)  \
# 0    1654.76                100.19     2510066.72   8977.19    2501089.53
# 1    1957.61                168.63     4469713.42  47882.55    4421830.87
# 2    4679.65                102.63     9283667.03  69370.32    9214296.71
# 3     420.18                 125.2       82066.20  43454.15      38612.05
# 4      Error                199.42            NaN  69673.69           NaN
#
# ...

# %%
crops.rename(columns={'Cost of Production (KES)':'COP','Crop Type': 'CP'})
# Out:
#     Farmer Name    County        CP      COP       Season  \
# 0      Farmer 1    Kiambu  Potatoes  Organic   Long Rains
# 1      Farmer 2      Meru    Coffee    Local  Short Rains
# 2      Farmer 3    Nakuru   Sorghum    Error   Long Rains
# 3      Farmer 4   Eldoret  Potatoes  Organic  Short Rains
# 4      Farmer 5  Machakos  Tomatoes   Hybrid  Short Rains
# ..          ...       ...       ...      ...          ...
# 495  Farmer 496   Eldoret  Potatoes   Hybrid   Dry Season
# 496  Farmer 497   Eldoret     Beans   Hybrid   Dry Season
# 497  Farmer 498       NaN     Beans  Organic   Dry Season
# 498  Farmer 499   Kericho   Cassava   Hybrid   Dry Season
# 499  Farmer 500      Meru       Tea  Organic   Dry Season
#
#     Planted Area (Acres) Yield (Kg) Market Price (KES/Kg)  Revenue (KES)  \
# 0                  15.14    1654.76                100.19     2510066.72
# 1                  13.54    1957.61                168.63     4469713.42
# ...

# %%
crops.columns=crops.columns.str.lower()
crops
# Out:
#     farmer name    county        cp      cop       season  \
# 0      Farmer 1    Kiambu  Potatoes  Organic   Long Rains
# 1      Farmer 2      Meru    Coffee    Local  Short Rains
# 2      Farmer 3    Nakuru   Sorghum    Error   Long Rains
# 3      Farmer 4   Eldoret  Potatoes  Organic  Short Rains
# 4      Farmer 5  Machakos  Tomatoes   Hybrid  Short Rains
# ..          ...       ...       ...      ...          ...
# 495  Farmer 496   Eldoret  Potatoes   Hybrid   Dry Season
# 496  Farmer 497   Eldoret     Beans   Hybrid   Dry Season
# 497  Farmer 498       NaN     Beans  Organic   Dry Season
# 498  Farmer 499   Kericho   Cassava   Hybrid   Dry Season
# 499  Farmer 500      Meru       Tea  Organic   Dry Season
#
#     planted area (acres) yield (kg) market price (kes/kg)  revenue (kes)  \
# 0                  15.14    1654.76                100.19     2510066.72
# 1                  13.54    1957.61                168.63     4469713.42
# ...

# %%
crops.columns=crops.columns.str.upper()
crops
# Out:
#     FARMER NAME    COUNTY        CP      COP       SEASON  \
# 0      Farmer 1    Kiambu  Potatoes  Organic   Long Rains
# 1      Farmer 2      Meru    Coffee    Local  Short Rains
# 2      Farmer 3    Nakuru   Sorghum    Error   Long Rains
# 3      Farmer 4   Eldoret  Potatoes  Organic  Short Rains
# 4      Farmer 5  Machakos  Tomatoes   Hybrid  Short Rains
# ..          ...       ...       ...      ...          ...
# 495  Farmer 496   Eldoret  Potatoes   Hybrid   Dry Season
# 496  Farmer 497   Eldoret     Beans   Hybrid   Dry Season
# 497  Farmer 498       NaN     Beans  Organic   Dry Season
# 498  Farmer 499   Kericho   Cassava   Hybrid   Dry Season
# 499  Farmer 500      Meru       Tea  Organic   Dry Season
#
#     PLANTED AREA (ACRES) YIELD (KG) MARKET PRICE (KES/KG)  REVENUE (KES)  \
# 0                  15.14    1654.76                100.19     2510066.72
# 1                  13.54    1957.61                168.63     4469713.42
# ...

# %%
crops.columns=crops.columns.str.replace(' ','_')
crops
# Out:
#     FARMER_NAME    COUNTY        CP      COP       SEASON  \
# 0      Farmer 1    Kiambu  Potatoes  Organic   Long Rains
# 1      Farmer 2      Meru    Coffee    Local  Short Rains
# 2      Farmer 3    Nakuru   Sorghum    Error   Long Rains
# 3      Farmer 4   Eldoret  Potatoes  Organic  Short Rains
# 4      Farmer 5  Machakos  Tomatoes   Hybrid  Short Rains
# ..          ...       ...       ...      ...          ...
# 495  Farmer 496   Eldoret  Potatoes   Hybrid   Dry Season
# 496  Farmer 497   Eldoret     Beans   Hybrid   Dry Season
# 497  Farmer 498       NaN     Beans  Organic   Dry Season
# 498  Farmer 499   Kericho   Cassava   Hybrid   Dry Season
# 499  Farmer 500      Meru       Tea  Organic   Dry Season
#
#     PLANTED_AREA_(ACRES) YIELD_(KG) MARKET_PRICE_(KES/KG)  REVENUE_(KES)  \
# 0                  15.14    1654.76                100.19     2510066.72
# 1                  13.54    1957.61                168.63     4469713.42
# ...

# %%
crops.columns=crops.columns.str.replace(' ','_').str.lower()
crops
# Out:
#     farmer_name    county        cp      cop       season  \
# 0      Farmer 1    Kiambu  Potatoes  Organic   Long Rains
# 1      Farmer 2      Meru    Coffee    Local  Short Rains
# 2      Farmer 3    Nakuru   Sorghum    Error   Long Rains
# 3      Farmer 4   Eldoret  Potatoes  Organic  Short Rains
# 4      Farmer 5  Machakos  Tomatoes   Hybrid  Short Rains
# ..          ...       ...       ...      ...          ...
# 495  Farmer 496   Eldoret  Potatoes   Hybrid   Dry Season
# 496  Farmer 497   Eldoret     Beans   Hybrid   Dry Season
# 497  Farmer 498       NaN     Beans  Organic   Dry Season
# 498  Farmer 499   Kericho   Cassava   Hybrid   Dry Season
# 499  Farmer 500      Meru       Tea  Organic   Dry Season
#
#     planted_area_(acres) yield_(kg) market_price_(kes/kg)  revenue_(kes)  \
# 0                  15.14    1654.76                100.19     2510066.72
# 1                  13.54    1957.61                168.63     4469713.42
# ...

# %%
crops['Country'] = 'Kenya'
crops
# Out:
#     farmer_name    county        cp      cop       season  \
# 0      Farmer 1    Kiambu  Potatoes  Organic   Long Rains
# 1      Farmer 2      Meru    Coffee    Local  Short Rains
# 2      Farmer 3    Nakuru   Sorghum    Error   Long Rains
# 3      Farmer 4   Eldoret  Potatoes  Organic  Short Rains
# 4      Farmer 5  Machakos  Tomatoes   Hybrid  Short Rains
# ..          ...       ...       ...      ...          ...
# 495  Farmer 496   Eldoret  Potatoes   Hybrid   Dry Season
# 496  Farmer 497   Eldoret     Beans   Hybrid   Dry Season
# 497  Farmer 498       NaN     Beans  Organic   Dry Season
# 498  Farmer 499   Kericho   Cassava   Hybrid   Dry Season
# 499  Farmer 500      Meru       Tea  Organic   Dry Season
#
#     planted_area_(acres) yield_(kg) market_price_(kes/kg)  revenue_(kes)  \
# 0                  15.14    1654.76                100.19     2510066.72
# 1                  13.54    1957.61                168.63     4469713.42
# ...

# %%
median_value = crops['profit_(kes)'].median()
median_value
# Out:
# 1660568.6099999999

# %%
mode_value = crops['profit_(kes)'].mode()
mode_value
# Out:
# 0        -38937.97
# 1        -36177.33
# 2        -34819.27
# 3        -23601.90
# 4        -21828.81
#           ...
# 399    11559963.62
# 400    12150703.64
# 401    12325597.02
# 402    12964279.45
# 403    13226742.98
# Name: profit_(kes), Length: 404, dtype: float64

# %%
mean_value = crops['profit_(kes)'].mean()
mean_value
# Out:
# np.float64(2714988.052029703)

# %%
crops['profit_(kes)'].fillna(mean_value, inplace=True)
crops.head()
# Out:
# /tmp/ipykernel_3602/2739329021.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   crops['profit_(kes)'].fillna(mean_value, inplace=True)
#   farmer_name    county        cp      cop       season planted_area_(acres)  \
# 0    Farmer 1    Kiambu  Potatoes  Organic   Long Rains                15.14
# 1    Farmer 2      Meru    Coffee    Local  Short Rains                13.54
# 2    Farmer 3    Nakuru   Sorghum    Error   Long Rains                19.33
# ...
